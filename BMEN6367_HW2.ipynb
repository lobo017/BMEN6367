# %% [markdown]
# <a href="https://colab.research.google.com/github/lobo017/BMEN6367/blob/main/BMEN6367_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2. List folders/files in your Google Drive to verify access
# !ls /content/drive/MyDrive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  101597036.pdf
# '2021-01-14 01-03.gdoc'
#  20240322_120156.jpg
#  20250715_234402.jpg
# 'ACN 6328 W2S1.gdoc'
# 'ACN 6395 exam 2 study guide.gdoc'
# 'ACN 6395 exam 2 study guide v0.gdoc'
# 'ACN 6395.gdoc'
# 'ACN 6V81 Exam 1.gdoc'
# 'ACN 6V81 Exam 2.gdoc'
# 'ACN 6V81.gdoc'
# "Aiden's Jeopardy Questions.gdoc"
# "Aiden's Jeopardy Questions V2.gdoc"
# 'Argumentative Essay Outline.gdoc'
#  ashley_kutcher.pdf
#  Attachment.jpeg
# 'Bad Visuals Example.pptx'
#  blank_ans.png
# 'Carlos Sotillo RESUME.gdoc'
#  ClassificationPractice.ipynb
#  Classroom
# 'Cognitive Science'
# 'Cognitive Science Homework.gdoc'
# 'Colab Notebooks'
# 'Copy of ETHAN LOBO - Darien Food Web- GOOGLE DOC - 13164424.gdoc'
#  CrucibleCasting.gslides
#  CrucibleCastingProject.gdoc
# 'CS 3345'
# 'CS 3354'
# 'Dashboard Feature Architecture & Complexity Hierarchy.gdoc'
#  Dashboard.gslides
# ...
