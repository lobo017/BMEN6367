# %% [markdown]
# <a href="https://colab.research.google.com/github/lobo017/BMEN6367/blob/main/BMEN6367_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 2: Colab, GitHub, Python Libraries, DFS, and BFS
#
# *   **Assignment Title:** BMEN 6367 - Homework 2
# *   **Student Name:** Ethan Lobo
# *   **GitHub Username:** lobo017
# *   **Date:** September 7, 2026

# %% [markdown]
# ## Section 1: Account Verification
#
# This section verifies the active status of my Google Drive and GitHub accounts.
#
# **Screenshot: Google Drive Workspace**
#
# ![image.png](data:image/png;base64,...)
#
# **Screenshot: GitHub Profile Dashboard**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Section 2: Linking Google Colab, Google Drive, and GitHub
#
# **Screenshot: Linked Colab, Drive, and GitHub Environment**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Section 3: Image Processing

# %% [markdown]
# ### Low-Pass Filtering (e.g., Gaussian Blur) Code

# %%
from scipy.ndimage import gaussian_filter
import numpy as np
import matplotlib.pyplot as plt
import cv2

path = "/content/drive/MyDrive/ethan headshot.jpg"

# Read the image using OpenCV
image = cv2.imread(path)

# Check if the image was loaded successfully
if image is None:
    print(f"Error: Could not load image from {path}")
else:
    # OpenCV reads images in BGR format, matplotlib expects RGB
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

blurred = gaussian_filter(image,sigma=(5,5,0))

fig, axes = plt.subplots(1,2,figsize=(12,6))

axes[0].imshow(image_rgb)
axes[0].set_title("Original Image")
axes[0].axis("off")

axes[1].imshow(blurred)
axes[1].set_title("Gaussian Blurred")
axes[1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Section 4: Depth-First Search (DFS) Implementation

# %%
graph = {
    'A': ['B', 'F'], 'B': ['A', 'C', 'G'], 'C': ['B', 'D', 'H'], 'D': ['C', 'E', 'I'], 'E': ['D', 'J'],
    'F': ['A', 'G', 'K'], 'G': ['B', 'F', 'H', 'L'], 'H': ['C', 'G', 'I', 'M'], 'I': ['D', 'H', 'J', 'N'], 'J': ['E', 'I', 'O'],
    'K': ['F', 'L', 'P'], 'L': ['G', 'K', 'M', 'Q'], 'M': ['H', 'L', 'N', 'R'], 'N': ['I', 'M', 'O', 'S'], 'O': ['J', 'N', 'T'],
    'P': ['K', 'Q', 'U'], 'Q': ['L', 'P', 'R', 'V'], 'R': ['M', 'Q', 'S', 'W'], 'S': ['N', 'R', 'T', 'X'], 'T': ['O', 'S', 'Y'],
    'U': ['P', 'V'], 'V': ['Q', 'U', 'W'], 'W': ['R', 'V', 'X'], 'X': ['S', 'W', 'Y'], 'Y': ['T', 'X']
}

# %%
visited = set()

def dfs(visited, graph, node):
  if node not in visited:
    print(node)
    visited.add(node)
    for neighbor in graph[node]:
      dfs(visited,graph,neighbor)

dfs(visited,graph,'A')
# Out:
# A
# B
# C
# D
# E
# J
# I
# H
# G
# F
# K
# L
# M
# N
# O
# T
# S
# R
# Q
# P
# U
# V
# W
# X
# Y

# %% [markdown]
# ## Section 5: Breadth-First Search (BFS) Implementation

# %%
visited = set()
queue = []

def bfs(visited,graph,node):
  visited.add(node)
  queue.append(node)

  while queue:
    s = queue.pop(0)

    print(s, end=" ")

    for neighbor in graph[s]:
      if neighbor not in visited:
        visited.add(neighbor)
        queue.append(neighbor)

bfs(visited,graph,'A')
# Out:
# A B F C G K D H L P E I M Q U J N R V O S W T X Y
